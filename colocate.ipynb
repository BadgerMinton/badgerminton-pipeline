# %%
import pandas as pd

df = pd.read_csv(
    "https://raw.githubusercontent.com/BadgerMinton/badgerminton-data/refs/heads/main/elo-scores/2024-11-28_elo_scores.csv"
)

result_df = df[df["played"] >= 20].reset_index(drop=True)
result_df.index = pd.RangeIndex(start=1, stop=len(result_df) + 1)
# result_df.sort_values(by=["event_change"])

display(result_df)
# Filter based on min 20 games played
# 28 November 2024
# Out:
#        name  played  wins  losses  scaled_rating  rating  event_change  \
# 1    Afiqah      38    30       8            7.8  1778.3             7
# 2      Isha      28    21       7            7.1  1711.7            30
# 3    Rushdi      34    21      13            6.7  1674.6            38
# 4     Ammar      28    19       9            6.7  1673.9            67
# 5    Hazwan      28    19       9            6.2  1620.7             3
# 6   Khairul      35    20      15            5.8  1577.6             1
# 7     Mirza      42    19      23            5.1  1511.1           -30
# 8   Mujahid      30    14      16            4.8  1478.3            -4
# 9   Shazwan      25    11      14            4.3  1426.3           -27
# 10    Nadia      38    16      22            4.1  1409.1           -22
# 11     Lisa      34    14      20            4.0  1398.5            43
# 12   Luqman      29     8      21            3.4  1344.7            -6
# 13  Yassier      42    12      30            2.6  1262.7           -53
#
#     total_change
# 1            278
# 2            212
# 3            175
# 4            174
# 5            121
# 6             78
# 7             11
# 8            -22
# 9            -74
# 10           -91
# 11          -101
# 12          -155
# 13          -237

# %%
result_df.sort_values(by=["event_change"])
# Out:
#        name  played  wins  losses  scaled_rating  rating  event_change  \
# 13  Yassier      42    12      30            2.6  1262.7           -53
# 7     Mirza      42    19      23            5.1  1511.1           -30
# 9   Shazwan      25    11      14            4.3  1426.3           -27
# 10    Nadia      38    16      22            4.1  1409.1           -22
# 12   Luqman      29     8      21            3.4  1344.7            -6
# 8   Mujahid      30    14      16            4.8  1478.3            -4
# 6   Khairul      35    20      15            5.8  1577.6             1
# 5    Hazwan      28    19       9            6.2  1620.7             3
# 1    Afiqah      38    30       8            7.8  1778.3             7
# 2      Isha      28    21       7            7.1  1711.7            30
# 3    Rushdi      34    21      13            6.7  1674.6            38
# 11     Lisa      34    14      20            4.0  1398.5            43
# 4     Ammar      28    19       9            6.7  1673.9            67
#
#     total_change
# 13          -237
# 7             11
# 9            -74
# 10           -91
# 12          -155
# 8            -22
# 6             78
# 5            121
# 1            278
# 2            212
# 3            175
# 11          -101
# 4            174

# %%
df.index = pd.RangeIndex(start=1, stop=len(df) + 1)
display(df)
# Full ranking
# 28 November 2024
# Out:
#         name  played  wins  losses  scaled_rating  rating  event_change  \
# 1     Afiqah      38    30       8            7.8  1778.3             7
# 2       Isha      28    21       7            7.1  1711.7            30
# 3     Rushdi      34    21      13            6.7  1674.6            38
# 4      Ammar      28    19       9            6.7  1673.9            67
# 5     Hazwan      28    19       9            6.2  1620.7             3
# 6       Aidi      11     8       3            5.9  1588.2           -34
# 7       Lina      15    10       5            5.9  1586.6            27
# 8    Khairul      35    20      15            5.8  1577.6             1
# 9     Suraya      17    11       6            5.6  1563.3            41
# 10     Haziq      14     9       5            5.6  1558.6            32
# 11     Kamil       4     3       1            5.5  1549.0            49
# 12    Suhayl      10     6       4            5.4  1537.6            36
# 13     Rafiq       8     5       3            5.3  1532.4            -5
# 14     Mirza      42    19      23            5.1  1511.1           -30
# 15      Alif      12     6       6            4.9  1494.7            -1
# 16     Sarah       8     4       4            4.9  1492.0            -8
# 17   Mujahid      30    14      16            4.8  1478.3            -4
# 18  Maisarah       7     3       4            4.7  1473.6           -26
# 19     Basit       4     1       3            4.7  1468.0           -32
# 20     Imran      11     5       6            4.6  1459.2            -3
# 21      Dina       5     1       4            4.6  1458.7           -41
# 22      Alya       7     1       6            4.3  1428.9           -71
# 23   Shazwan      25    11      14            4.3  1426.3           -27
# 24  Zulhakim       9     3       6            4.2  1420.0           -74
# 25     Nadia      38    16      22            4.1  1409.1           -22
# 26      Lisa      34    14      20            4.0  1398.5            43
# 27      Faiz      11     2       9            3.8  1375.5           -95
# 28  Suhailah       9     1       8            3.7  1369.3           -80
# 29    Luqman      29     8      21            3.4  1344.7            -6
# 30   Hasanah      15     1      14            2.8  1276.8           -76
# 31   Yassier      42    12      30            2.6  1262.7           -53
#
#     total_change
# 1            278
# 2            212
# 3            175
# 4            174
# 5            121
# 6             88
# 7             87
# 8             78
# 9             63
# 10            59
# 11            49
# 12            38
# 13            32
# 14            11
# 15            -5
# 16            -8
# 17           -22
# 18           -26
# 19           -32
# 20           -41
# 21           -41
# 22           -71
# 23           -74
# 24           -80
# 25           -91
# 26          -101
# 27          -124
# 28          -131
# 29          -155
# 30          -223
# 31          -237
