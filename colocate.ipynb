# %%
import pandas as pd

df = pd.read_csv(
    "https://raw.githubusercontent.com/BadgerMinton/badgerminton-data/refs/heads/main/elo-scores/2024-12-12_elo_scores.csv"
)

result_df = df[df["played"] >= 20].reset_index(drop=True)
result_df.index = pd.RangeIndex(start=1, stop=len(result_df) + 1)

display(result_df)
# Filter based on min 20 games played
# 12 December 2024
# Out:
#        name  played  wins  losses  scaled_rating  rating  event_change  \
# 1    Afiqah      50    38      12            8.0  1802.5            41
# 2      Isha      33    24       9            7.1  1706.4            -5
# 3     Ammar      40    27      13            7.0  1701.3           -37
# 4    Hazwan      40    26      14            6.6  1657.4            23
# 5      Lina      20    13       7            6.2  1620.7            34
# 6    Suraya      21    15       6            6.1  1612.1            49
# 7    Rushdi      41    23      18            6.1  1609.2           -65
# 8   Khairul      41    23      18            5.8  1584.7             7
# 9   Mujahid      40    21      19            5.6  1556.6            45
# 10     Alif      23    13      10            5.3  1527.4             6
# 11  Shazwan      33    16      17            4.7  1465.5            19
# 12    Mirza      53    22      31            4.3  1426.7           -84
# 13     Lisa      39    15      24            3.5  1354.5           -44
# 14  Yassier      54    18      36            3.4  1342.3            51
# 15    Nadia      49    19      30            3.1  1312.0           -24
# 16   Luqman      35     9      26            2.9  1290.9           -54
# 17  Hasanah      20     1      19            2.0  1201.7           -75
#
#     total_change
# 1            302
# 2            206
# 3            201
# 4            157
# 5            121
# 6            112
# 7            109
# 8             85
# 9             57
# 10            27
# 11           -34
# 12           -73
# 13          -145
# 14          -158
# 15          -188
# 16          -209
# 17          -298

# %%
result_df.sort_values(by=["event_change"])
# Out:
#        name  played  wins  losses  scaled_rating  rating  event_change  \
# 12    Mirza      53    22      31            4.3  1426.7           -84
# 17  Hasanah      20     1      19            2.0  1201.7           -75
# 7    Rushdi      41    23      18            6.1  1609.2           -65
# 16   Luqman      35     9      26            2.9  1290.9           -54
# 13     Lisa      39    15      24            3.5  1354.5           -44
# 3     Ammar      40    27      13            7.0  1701.3           -37
# 15    Nadia      49    19      30            3.1  1312.0           -24
# 2      Isha      33    24       9            7.1  1706.4            -5
# 10     Alif      23    13      10            5.3  1527.4             6
# 8   Khairul      41    23      18            5.8  1584.7             7
# 11  Shazwan      33    16      17            4.7  1465.5            19
# 4    Hazwan      40    26      14            6.6  1657.4            23
# 5      Lina      20    13       7            6.2  1620.7            34
# 1    Afiqah      50    38      12            8.0  1802.5            41
# 9   Mujahid      40    21      19            5.6  1556.6            45
# 6    Suraya      21    15       6            6.1  1612.1            49
# 14  Yassier      54    18      36            3.4  1342.3            51
#
#     total_change
# 12           -73
# 17          -298
# 7            109
# 16          -209
# 13          -145
# 3            201
# 15          -188
# 2            206
# 10            27
# 8             85
# 11           -34
# 4            157
# 5            121
# 1            302
# 9             57
# 6            112
# 14          -158

# %%
df.index = pd.RangeIndex(start=1, stop=len(df) + 1)
display(df)
# Full ranking
# 12 December 2024
# Out:
#         name  played  wins  losses  scaled_rating  rating  event_change  \
# 1     Afiqah      50    38      12            8.0  1802.5            41
# 2       Isha      33    24       9            7.1  1706.4            -5
# 3      Ammar      40    27      13            7.0  1701.3           -37
# 4     Hazwan      40    26      14            6.6  1657.4            23
# 5       Lina      20    13       7            6.2  1620.7            34
# 6     Suraya      21    15       6            6.1  1612.1            49
# 7     Rushdi      41    23      18            6.1  1609.2           -65
# 8      Haziq      19    12       7            5.9  1592.6            34
# 9       Aidi      11     8       3            5.9  1588.2           -34
# 10   Khairul      41    23      18            5.8  1584.7             7
# 11    Suhayl      13     8       5            5.6  1562.5            25
# 12   Mujahid      40    21      19            5.6  1556.6            45
# 13     Kamil       4     3       1            5.5  1549.0            49
# 14     Rafiq       8     5       3            5.3  1532.4            -5
# 15     Zarif       6     4       2            5.3  1528.5            29
# 16      Alif      23    13      10            5.3  1527.4             6
# 17     Sarah       8     4       4            4.9  1492.0            -8
# 18  Maisarah       7     3       4            4.7  1473.6           -26
# 19     Basit       4     1       3            4.7  1468.0           -32
# 20   Shazwan      33    16      17            4.7  1465.5            19
# 21     Imran      11     5       6            4.6  1459.2            -3
# 22      Dina       5     1       4            4.6  1458.7           -41
# 23   Hidayat       4     0       4            4.3  1429.8           -70
# 24      Alya       7     1       6            4.3  1428.9           -71
# 25     Mirza      53    22      31            4.3  1426.7           -84
# 26  Zulhakim       9     3       6            4.2  1420.0           -74
# 27      Faiz      11     2       9            3.8  1375.5           -95
# 28  Suhailah       9     1       8            3.7  1369.3           -80
# 29      Lisa      39    15      24            3.5  1354.5           -44
# 30   Yassier      54    18      36            3.4  1342.3            51
# 31     Nadia      49    19      30            3.1  1312.0           -24
# 32    Luqman      35     9      26            2.9  1290.9           -54
# 33   Hasanah      20     1      19            2.0  1201.7           -75
#
#     total_change
# 1            302
# 2            206
# 3            201
# 4            157
# 5            121
# 6            112
# 7            109
# 8             93
# 9             88
# 10            85
# 11            63
# 12            57
# 13            49
# 14            32
# 15            29
# 16            27
# 17            -8
# 18           -26
# 19           -32
# 20           -34
# 21           -41
# 22           -41
# 23           -70
# 24           -71
# 25           -73
# 26           -80
# 27          -124
# 28          -131
# 29          -145
# 30          -158
# 31          -188
# 32          -209
# 33          -298
